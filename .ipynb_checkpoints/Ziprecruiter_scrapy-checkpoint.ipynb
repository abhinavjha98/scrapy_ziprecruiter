# %%
import pandas as pd
import re
import requests
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
from datetime import date, timedelta, datetime
from IPython.core.display import clear_output
from random import randint
from requests import get
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from time import sleep
from time import time
start_time = time()
import urllib.request
from warnings import warn
import math

url = "https://www.ziprecruiter.com/candidate/search?search=&location=bismarck%2C++nd"
browser = webdriver.Chrome("chromedriver.exe")
browser.get(url)
browsers = webdriver.Chrome("chromedriver.exe")
browsers.get(url)
import secrets 
import string 
  
# initializing size of string  
N = 7
  
# using random.choices() 
# generating random strings  
res = ''.join(secrets.choice(string.ascii_lowercase + string.digits) 
                                                  for i in range(N)) 

username = browser.find_element_by_id("email_address")
username.send_keys(str(res)+"@gmail.com")
browser.find_element_by_xpath("//input[@type='submit' and @value='Continue']").click()
sleep(5)
elems = browser.find_element_by_xpath("//button[contains(@class, 'load_more_jobs')]").click()
sleep(5)
aa = 0
browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
while True:
    dataa = browser.current_url
    a = browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(3)
    datac = browser.current_url
    if dataa == datac:
        aa = aa +1
        if aa == 5:
            print(dataa,datac)
            break
    
links = datac
parse_link = links.split("&page=")
i = 1
pp=[]
for i in range(int(parse_link[1])+1):
    if i == 0:
        continue
    else:
        pp.append(parse_link[0]+"&page="+str(i))
# Out:
# https://www.ziprecruiter.com/candidate/search?search=&location=bismarck%2C++nd&page=2 https://www.ziprecruiter.com/candidate/search?search=&location=bismarck%2C++nd&page=2

# %%
job_title = []
company = []
location = []
salary = []
emp_type = []
description = []
imgs = []
link_view = []
for k in pp:
    browser.get(k)
    try:
        job_tit=browser.find_elements_by_class_name("just_job_title")
        for j in job_tit:
            job_title.append(j.text)
    except NoSuchElementException:
        job_title.append("")
        
    try:
        descript=browser.find_elements_by_class_name("job_snippet")
        for i in descript:
            description.append(i.text)
    except NoSuchElementException:
        description.append("")
    
    try:
        cpm=browser.find_elements_by_class_name("t_org_link")
        for i in cpm:
            company.append(i.text)
    except NoSuchElementException:
        company.append("")
    
    try:
        emp_typ=browser.find_elements_by_class_name("data_item")
        for i in emp_typ:
            if "$" in i.text:
                pass
            else:
                emp_type.append(i.text)
    except NoSuchElementException:
        emp_typ.append("")
    try:
        loca = browser.find_elements_by_class_name("t_location_link")
        for i in loca:
            location.append(i.text)
    except NoSuchElementException:
        location.append("")   
    try:
        img_logo = browser.find_elements_by_xpath("//p/img")
        for i in img_logo:
            if "business.svg" in i.get_attribute("src"):
                imgs.append(" ")
            else:
                imgs.append(i.get_attribute("src"))
    except NoSuchElementException:
        imgs.append("")

# %%
link_view = []
for j in pp:
    browser.get(j)
    try:
        elems = browser.find_elements_by_xpath("//a[contains(@class, 't_job_link')]")
        for elem in elems:
            try:
                r = requests.get(elem.get_attribute("href")) 
                browsers.get(r.url)
                link_view.append(browsers.current_url)
            except AttributeError:
                link_view.append("")
            except requests.exceptions.ConnectionError:
                r.status_code = "Connection refused"
    except NoSuchElementException:
        link_view.append("")


import pandas as pd 
   
lst = [job_title,company,location,salary,emp_type,description] 
 
df = pd.DataFrame(list(zip(imgs,job_title,location,company,description,link_view,emp_type)), columns =['Logo','Title','Location','Company','Description','ApplyLink','Job_type']) 
df
df.to_csv('ZipRecuitessa.csv',index=False)
# Out:
# https://simpleapply-asm.icims.com/jobs/295283/job?mode=apply&iis=Job+Board&iisn=ZipRecruiter
# https://www.safeguardvendors.com/?zip
# https://www.ziprecruiter.com/jobs/aflac-39e92651/insurance-sales-agent-03cf5eae?lvk=e34RWlAVHFBHeFRDiGU64Q.--LnLl8F0gg
# https://nexrep.com/inbound-sales-rep-hw/?srcdid=100800
# https://jobs.lumen.com/global/en/job/236441/Call-Center-Representative-Billing-Bismarck-ND?jobsource=recruitics&rx_campaign=reach44&rx_group=120235&rx_job=236441&rx_medium=cpc&rx_r=cpa&rx_source=reach-ziprecruiter&rx_ts=20201123T123953Z&utm_medium=phenom-feeds&utm_source=ReachRecruitics&rx_p=24274581-1cf8-48db-aa69-ce4aeaddcec5&rx_viewer=6bed25be2d9611ebb549b706ae55a9b685c099eeaed545179d221dbd65ac1fda
# https://careers.peopleclick.com/careerscp/client_safetykleen/external_cleanharbors/gateway/applyFromLink.html?source=ZipRecruiter&jobPostId=131165&localeCode=en-us&sourceType=PREMIUM_POST_SITE
# https://drive4pride.com/?utm_source=ziprecruiter&utm_medium=cpc&utm_campaign=1minpop_cd_solo_nd_ziprecruiter&r=leadflex_zip_cd_solo&id=37283-224-1993371371
# https://wylietough.com/jobs/?ad=1789_8497_Bismarck_ND&v=wylietoughrms&location=bis&category=e-w-wylie-company-drivers&title=cdl-a-flatbed-company-drivers-needed&referrer=Appvault_med241_DT003_RT006_FT005&utm_source=Programmatic&phone=888-818-2885
# https://cdljobnow.com/company/1441/roehl-dry-van/11075?utm_source=clickcast&utm_medium=ziprecruiter&utm_campaign=Roehl&utm_content=1441&cdljn_source=11075&jid=CDLJN-2020-11-23-Gray-GA-199-53385ac2b0bbef6e2a30ea512ed6e4dc&ccuid=28434550614
# https://atwork.appvault.com/BismarckTribune/jobs/?ad=18014-1_600461&v=BismarckTribuneRMS&utm_source=programmatic2&utm_medium=ppc&utm_campaign=General_Positions
# https://join.assurance.com/life-insurance-agent?utm_source=appcastpremium&utm_medium=28434553169&utm_content=life&utm_term=ziprecruiter
# https://careers-agencystaffcandidate.icims.com/jobs/2489/login?mode=prepopulate&iis=ZipRecruiter&iisn=ZipRecruiter&mode=prepopulate&iis=external&iisn=ZipRecruiter
# https://careers-agencystaffcandidate.icims.com/jobs/2489/login?mode=prepopulate&iis=ZipRecruiter&iisn=ZipRecruiter&mode=prepopulate&iis=external&iisn=ZipRecruiter
